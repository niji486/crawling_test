# %%
# 클래스 선언
class Bicycle():  
  pass # 클래스의 원형만 선언 후 pass만 있어서 실제로는 아무일도 일어나지 않으나 엄연한 클래스임.

# %%
# 선언된 클래스로부터 클래스의 인스턴스인 객체를 생성하는 방법
my_bicycle = Bicycle()
my_bicycle   #객체를 실행하면 생성할 때 할당받은 메모리의 주소값을 출력함.

# %%
# 출력 결과에서 my_bicycle 객체의 클래스는 Bicycle임을 확인할 수 있음

# %%
#생성한 my_bicycle 객체에 속성값을 설정.
#바퀴크기 : wheel_size, 색상 : color

my_bicycle.wheel_size = 26
my_bicycle.color = 'black'

# %%
print("바퀴크기 :", my_bicycle.wheel_size) # 객체의 속성 출력
print("색상:", my_bicycle.color)
# Out:
# 바퀴크기 : 26
# 색상: black

# %%
#선언한 Bicycle 클래스에 함수 추가 
# 속도 move, 좌/우회전 turn, 정지 stop
class Bicycle() : 

  def move(self, speed) : 
    print("자전거 : 시속 {0}킬로미터로 전진".format(speed))

  def turn(self, direction) : 
    print("자전거 : {0}회전".format(direction))
  
  def stop(self):
    print("자전거({0},{1}) : 정지".format(self.wheel_size, self.color))

# %%
 #Bicycle 클래스에서 my_bicycle 객체를 생성한 후 속성을 설정하고 메서드를 호출

my_bicycle = Bicycle() 

my_bicycle.wheel_size = 26
my_bicycle.color = 'black'

my_bicycle.move(30)
my_bicycle.turn('좌')
my_bicycle.stop()
# Out:
# 자전거 : 시속 30킬로미터로 전진
# 자전거 : 좌회전
# 자전거(26,black) : 정지

# %%
# Bicycle  클래스를 이용해 필요한 만큼의 객체를 만들 수 있음. 
my_bicycle1 = Bicycle() 

my_bicycle.wheel_size = 27
my_bicycle.color = 'red'

my_bicycle.move(20)
my_bicycle.turn('좌')
my_bicycle.stop()
# Out:
# 자전거 : 시속 20킬로미터로 전진
# 자전거 : 좌회전
# 자전거(27,red) : 정지

# %%
class Bicycle() : 

  def __init__(self, wheel_size, color):
    self.wheel_size = wheel_size    # 객체 생성과 동시에 속성값을 지정 
    self.color = color

  def move(self, speed) : 
    print("자전거 : 시속 {0}킬로미터로 전진".format(speed))

  def turn(self, direction) : 
    print("자전거 : {0}회전".format(direction))
  
  def stop(self):
    print("자전거({0},{1}) : 정지".format(self.wheel_size, self.color))

# %%
my_bicycle = Bicycle(26, 'black')  # 객체 생성과 동시에 속성값을 지정 

my_bicycle.move(30)
my_bicycle.turn('좌')
my_bicycle.stop()
# Out:
# 자전거 : 시속 30킬로미터로 전진
# 자전거 : 좌회전
# 자전거(26,black) : 정지

# %%
class Car():
  instance_count = 0 # 클래스 변수 생성 및 초기화 

  def __init__(self, size, color) : 
    self.size = size # 인스턴스 변수 생성 및 초기화 
    self.color = color # 인스턴스 변수 생성 및 초기화
    Car.instance_count = Car.instance_count + 1 # 클래스 변수 이용 
    print("자동차 객체의 수 : {0}".format(Car.instance_count))
  
  def move(self) :
    print("자동차({0} &{1})가 움직입니다.".format(self.size, self.color))

# %%
car1 = Car('small', 'white')
car2 = Car('big', 'black')

print("Car 클래스의 총 인스턴스 개수:{}".format(Car.instance_count))
# Out:
# 자동차 객체의 수 : 5
# 자동차 객체의 수 : 6
# Car 클래스의 총 인스턴스 개수:6

# %%
print("Car 클래스의 총 인스턴스 개수:{}".format(car1.instance_count))
# Out:
# Car 클래스의 총 인스턴스 개수:6

# %%
print("Car 클래스의 총 인스턴스 개수:{}".format(car2.instance_count))
# Out:
# Car 클래스의 총 인스턴스 개수:6

# %%
car1.move()
# Out:
# 자동차(small &white)가 움직입니다.

# %%
car2.move()
# Out:
# 자동차(big &black)가 움직입니다.
