# %%
1+1
# Out:
# 2

# %%
5 - 2
# Out:
# 3

# %%
15 * 2
# Out:
# 30

# %%
10 / 2
# Out:
# 5.0

# %%
1.2+5.3
# Out:
# 6.5

# %%
3.5-5.0
# Out:
# -1.5

# %%
1.4*2
# Out:
# 2.8

# %%
5/2
# Out:
# 2.5

# %%
2+3*4
# Out:
# 14

# %%
3/2*4-5/2
# Out:
# 3.5

# %%
10/5+(5-2)*2
# Out:
# 8.0

# %%
(5*4-15)+((5-2)*(9-7))
# Out:
# 11

# %%
type(3)
# Out:
# int

# %%
type(1.2)
# Out:
# float

# %%
2*2*2*2*2
# Out:
# 32

# %%
2**5
# Out:
# 32

# %%
1.5**2
# Out:
# 2.25

# %%
2**(1/2)
# Out:
# 1.4142135623730951

# %%
13%5
# Out:
# 3

# %%
13//5
# Out:
# 2

# %%
14//6
# Out:
# 2

# %%
14%6
# Out:
# 2

# %%
3*10**8
# Out:
# 300000000

# %%
3e8
# Out:
# 300000000.0

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1e16
# Out:
# 1e+16

# %%
1e16
# Out:
# 1e+16

# %%
e16
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-79567940cf52> in <module>()
# ----> 1 e16
#
# NameError: name 'e16' is not defined

# %%
2e16
# Out:
# 2e+16

# %%
1e-4
# Out:
# 0.0001

# %%
1e-5
# Out:
# 1e-05

# %%
1e+16
# Out:
# 1e+16

# %%
1e16
# Out:
# 1e+16

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1+2e4
# Out:
# 20001.0

# %%
bin(17)
# Out:
# '0b10001'

# %%
oct(17)
# Out:
# '0o21'

# %%
hex(17)
# Out:
# '0x11'

# %%
0b10001
# Out:
# 17

# %%
17
# Out:
# 17

# %%
0b10001
# Out:
# 17

# %%
0o21
# Out:
# 17

# %%
0x11
# Out:
# 17

# %%
0b10
# Out:
# 2

# %%
0b10*0o10+ox10-10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7a3979942840> in <module>()
# ----> 1 0b10*0o10+ox10-10
#
# NameError: name 'ox10' is not defined

# %%
0b10*0o10+0x10-10
# Out:
# 22

# %%
bin(ob10*0o10+0x10-10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-d3a79f1d1d86> in <module>()
# ----> 1 bin(ob10*0o10+0x10-10)
#
# NameError: name 'ob10' is not defined

# %%
bin(0b10*0o10+0x10-10)
# Out:
# '0b10110'

# %%
oct(0b10*0o10+0x10-10)
# Out:
# '0o26'

# %%
0b10110
# Out:
# 22

# %%
hex(0b10*0o10+0x10-10)
# Out:
# '0x16'

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-d6f700e50a15> in <module>()
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
print(True and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
print(5==3)
# Out:
# False

# %%
print(5!=3)
# Out:
# True

# %%
print((3<0)and((-5>0)and(1>5)))
# Out:
# False

# %%
print(((3>0)or(-5>0))and((4>8)or(3<0)))
# Out:
# False
