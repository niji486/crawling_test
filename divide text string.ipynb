# %%
coffee_menu_str = "에스프레스, 아메리카노, 카페라떼, 카푸치노"
coffee_menu_str.split(',')
# Out:
# ['에스프레스', ' 아메리카노', ' 카페라떼', ' 카푸치노']

# %%
phone_number="+82-10-2345-6789"
split_num=phone_number.split("-",1)

# %%
print(split_num)
# Out:
# ['+82', '10-2345-6789']

# %%
print("국내전화번호:0{0}".format(split_num[1]))
# Out:
# 국내전화번호:010-2345-6789

# %%
"에스프레스, 아메리카노, 카페라떼, 카푸치노".split(',')
# Out:
# ['에스프레스', ' 아메리카노', ' 카페라떼', ' 카푸치노']

# %%
"에스프레스, 아메리카노, 카페라떼, 카푸치노".split(' ')
# Out:
# ['에스프레스,', '아메리카노,', '카페라떼,', '카푸치노']

# %%
"에스프레스, 아메리카노, 카페라떼, 카푸치노".split()
# Out:
# ['에스프레스,', '아메리카노,', '카페라떼,', '카푸치노']

# %%
"      에스프레스 \n\n    아메리카노 \n\n   카페라떼 \n\n   카푸치노 \n\n".split()
# Out:
# ['에스프레스', '아메리카노', '카페라떼', '카푸치노']

# %%
"에스프레스, 아메리카노, 카페라떼, 카푸치노".split(maxsplit=2)
# Out:
# ['에스프레스,', '아메리카노,', '카페라떼, 카푸치노']

# %%
"aaaBallaaa".strip('a')
# Out:
# 'Ball'

# %%
"\n This is very \n fast \n\n".strip()
# Out:
# 'This is very \n fast'

# %%
coffee_menu=" 에스프레소, 아메리카오, 카페라떼, 카푸치오 "
coffee_menu_list=coffee_menu.split(',')
coffee_menu_list
# Out:
# [' 에스프레소', ' 아메리카오', ' 카페라떼', ' 카푸치오 ']

# %%
coffee_list = [] #빈 리스트 생성
for coffee in coffee_menu_list:
  temp = coffee.strip() # 문자열의 공백 제거
  coffee_list.append(temp) #리스트 변수에 공백이 제거된 문자열 추가 

print(coffee_list) #최종 문자열 리스트 출력
# Out:
# ['에스프레소', '아메리카오', '카페라떼', '카푸치오']

# %%
address_list= ["서울시", "서초구", "반포대로", "201(반포동)"]
address_list
# Out:
# ['서울시', '서초구', '반포대로', '201(반포동)']

# %%
a = " "
a.join(address_list)
# Out:
# '서울시 서초구 반포대로 201(반포동)'

# %%
address_list
# Out:
# ['서울시', '서초구', '반포대로', '201(반포동)']

# %%
"☆".join(address_list)
# Out:
# '서울시☆서초구☆반포대로☆201(반포동)'

# %%
str_f= "communication code."
print(str_f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-d2653d1c4a84> in <module>()
#       1 str_f="communication code"
# ----> 2 print(str_f)
#
# TypeError: 'tuple' object is not callable
