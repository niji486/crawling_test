# %%
def my_student_info_list(student_info):
  print("****************************")
  print("* 학생이름:", student_info[0])
  print("* 학급번호:", student_info[1])
  print("* 전화번호:", student_info[2])
  print("****************************")
student1_info = ["현아","01","01-234-5678"]
my_student_info_list(student1_info)
# Out:
# ****************************
# * 학생이름: 현아
# * 학급번호: 01
# * 전화번호: 01-234-5678
# ****************************

# %%
my_student_info_list(["지연","02","01-234-5679"])
# Out:
# ****************************
# * 학생이름: 지연
# * 학급번호: 02
# * 전화번호: 01-234-5679
# ****************************

# %%
def my_func() : 
  print("My first function")
  print("This is a function")
  
my_func()
# Out:
# My first function
# This is a function

# %%
def my_friend(friendName):
  print("{}는 나의 친구입니다.". format(friendName))

# %%
my_friend("영수")
# Out:
# 영수는 나의 친구입니다.

# %%
a = 5 #전역변수

def func1():
  a = 1 #지역 변수, func1()에서만 사용
  print("[func1] 지역 변수 a=", a)

def func2():
  a = 2 #지역 변수, func2()에서만 사용
  print("[func2] 지역 변수 a=", a)

def func3():
  a = 3 #지역 변수, func2()에서만 사용
  print("[func3] 지역 변수 a=", a)

def func4():
  global a # 함수 내에서 전역 변수 변경 위해 선언
  a = 4 #전역 범수의 값 변경
  print("[func4] 전역 변수 a=", a)

# %%
func1()
func2()
print("전역 변수 a=", a)
# Out:
# [func1] 지역 변수 a= 1
# [func2] 지역 변수 a= 2
# 전역 변수 a= 5

# %%
func3()
func4()
func3()
# Out:
# [func3] 지역 변수 a= 3
# [func4] 지역 변수 a= 4
# [func3] 지역 변수 a= 3

# %%
mySimpleFunc = lambda x,y,z : 2*x + 3*y +z
mySimpleFunc(1,2,3)
# Out:
# 11

# %%
[int(0.123), int(3.512), int(-1.3425)]
# Out:
# [0, 3, -1]

# %%
[int('1234'), int('5678')]
# Out:
# [1234, 5678]

# %%
float(0)
# Out:
# 0.0

# %%
[float(0), float(123), float(-567)]
# Out:
# [0.0, 123.0, -567.0]

# %%
[str(123)]
# Out:
# ['123']

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True
