# %%
import random
random.random()
# Out:
# 0.851558364272969

# %%
import random

dice1 = random.randint(1,6)
dice2 = random.randint(1,6)
print('주사위 두개의 숫자 : {0}, {1}'.format(dice1, dice2))
# Out:
# 주사위 두개의 숫자 : 4, 1

# %%
import random

num1=random.randrange(1,10,2) #1~9 중 임의의 홀수 선택 
num2=random.randrange(0, 100, 10)  #0~99 중 임의의 10 단위 숫자 선택 
print('num1:{0}, num2:{1}'.format(num1, num2))
# Out:
# num1:1, num2:90

# %%
import random

menu = ['비빔밥', '된장찌개', '볶음밥', '불고기', '스파게티']
random.choice(menu)
# Out:
# '불고기'

# %%
import random 
random.sample(['비빔밥', '된장찌개', '볶음밥', '불고기', '스파게티'],2) # 모집단에서 두 개의 인자 선택
# Out:
# ['스파게티', '불고기']

# %%
import datetime
set_day=datetime.date(2021,8,2)
print(set_day)
# Out:
# 2021-08-02

# %%
print('{0}/{1}/{2}'.format(set_day.year, set_day.month, set_day.day))
# Out:
# 2021/8/2

# %%
import datetime

day1=datetime.date(2021,4,1)
day2=datetime.date(2021,7,10)
diff_day=day2 - day1
print(diff_day)
# Out:
# 100 days, 0:00:00

# %%
type(day1)
# Out:
# datetime.date

# %%
type(diff_day)
# Out:
# datetime.timedelta

# %%
print("** 지정된 두 날짜의 차이는 {}입니다".format(diff_day.days))
# Out:
# ** 지정된 두 날짜의 차이는 100입니다

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2021-08-04 02:49:26.867295
